# %%
import eli5
from disk_utils import disk_cache

@disk_cache
def load_model():
    pass
@disk_cache
def load_data():
    pass

# %%
model = load_model()
eli5.show_weights(model)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>c1</th>
#
#                 <th>c2</th>
#
#                 <th>other</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>c1</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="c1 &rArr; c1">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 91.59%)" title="c1 &rArr; c2">
#                             -5.139
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 84.16%)" title="c1 &rArr; other">
#                             12.706
#                         </td>
#
# ...

# %%
x, y, q = load_data()

# %%
x[88380], y[88380], q[88380]
print([x_['0'] for x_ in x[88380]])
model.predict([x[88380]])
print(q[88380])
# Out:
# ['VERB', 'PROPN', 'VERB', 'ADP', 'PROPN', 'PUNCT']
# Is Dromesnil located in Amiens ?
